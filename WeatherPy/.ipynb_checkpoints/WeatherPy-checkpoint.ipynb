# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress, pearsonr

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# !pip install citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500) #lower range, upper range, how many numbers
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500) #equal likely change to chose the same numbers. uniform distribution
lat_lngs = zip(lats, lngs) #puts it into pair like "zipper" them together, taking two lists and putting into one list

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 606

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial"
city_url = url + "&q=" + cities[0] 

city_weather = requests.get(city_url).json()


city_weather
# Out:
# {'coord': {'lon': 70.2167, 'lat': -49.35},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 37.71,
#   'feels_like': 25.11,
#   'temp_min': 37.71,
#   'temp_max': 37.71,
#   'pressure': 1009,
#   'humidity': 76,
#   'sea_level': 1009,
#   'grnd_level': 1008},
#  'visibility': 10000,
#  'wind': {'speed': 31.9, 'deg': 248, 'gust': 37.49},
#  'clouds': {'all': 73},
#  'dt': 1690058495,
#  'sys': {'country': 'TF', 'sunrise': 1690081248, 'sunset': 1690113003},
#  'timezone': 18000,
#  'id': 1546102,
#  'name': 'Port-aux-Français',
#  'cod': 200}

# %%
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
city_lat = city_weather["coord"]["lat"]
city_lng = city_weather["coord"]["lon"]
city_max_temp = city_weather["main"]["temp_max"]
city_humidity = city_weather["main"]["humidity"]
city_clouds = city_weather["clouds"]["all"]
city_wind = city_weather["wind"]["speed"]
city_country = city_weather["sys"]["country"]
city_date = city_weather["dt"]

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial"
#make sure to put api key {} so it knows to bring it in and the f at the beginning

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city 
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | dickinson
# Processing Record 3 of Set 1 | bestobe
# Processing Record 4 of Set 1 | luanda
# Processing Record 5 of Set 1 | iqaluit
# Processing Record 6 of Set 1 | cam ranh
# Processing Record 7 of Set 1 | college
# Processing Record 8 of Set 1 | princeville
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | margaret river
# Processing Record 11 of Set 1 | badger
# Processing Record 12 of Set 1 | altamira
# Processing Record 13 of Set 1 | contamana
# Processing Record 14 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | seogwipo
# City not found. Skipping...
# Processing Record 17 of Set 1 | stanley
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | al kharijah
# Processing Record 20 of Set 1 | tchibanga
# Processing Record 21 of Set 1 | moranbah
# Processing Record 22 of Set 1 | aquin
# Processing Record 23 of Set 1 | hadibu
# Processing Record 24 of Set 1 | waitangi
# Processing Record 25 of Set 1 | 'anat al qadimah
# Processing Record 26 of Set 1 | wailua homesteads
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | grytviken
# Processing Record 29 of Set 1 | uturoa
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | afaahiti
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | puerto san jose
# Processing Record 34 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 35 of Set 1 | isafjordur
# Processing Record 36 of Set 1 | thunder bay
# Processing Record 37 of Set 1 | kudahuvadhoo
# Processing Record 38 of Set 1 | rongelap
# Processing Record 39 of Set 1 | chonchi
# Processing Record 40 of Set 1 | st. john's
# Processing Record 41 of Set 1 | puerto natales
# Processing Record 42 of Set 1 | massaguet
# Processing Record 43 of Set 1 | ilulissat
# Processing Record 44 of Set 1 | la passe
# Processing Record 45 of Set 1 | aberdeen
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | vorgashor
# Processing Record 48 of Set 1 | acapulco de juarez
# Processing Record 49 of Set 1 | opuwo
# Processing Record 50 of Set 1 | adamstown
# Processing Record 0 of Set 2 | siwa oasis
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | sarykemer
# Processing Record 4 of Set 2 | kruisfontein
# Processing Record 5 of Set 2 | aral
# Processing Record 6 of Set 2 | leua
# Processing Record 7 of Set 2 | knyaze-volkonskoye
# Processing Record 8 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record
# Processing Record 39 of Set 3 | vohipaho
# City not found. Skipping...
# Processing Record 40 of Set 3 | parry sound
# Processing Record 41 of Set 3 | edd
# Processing Record 42 of Set 3 | purpe
# Processing Record 43 of Set 3 | atafu village
# Processing Record 44 of Set 3 | bethel
# Processing Record 45 of Set 3 | crane
# Processing Record 46 of Set 3 | nar'yan-mar
# Processing Record 47 of Set 3 | vernon
# Processing Record 48 of Set 3 | aras-asan
# Processing Record 49 of Set 3 | fort st. john
# Processing Record 0 of Set 4 | hithadhoo
# Processing Record 1 of Set 4 | chardara
# Processing Record 2 of Set 4 | alice springs
# Processing Record 3 of Set 4 | san antonio de pale
# Processing Record 4 of Set 4 | nikolayevsk-on-amure
# Processing Record 5 of Set 4 | bafia
# Processing Record 6 of Set 4 | prince rupert
# Processing Record 7 of Set 4 | isla mujeres
# Processing Record 8 of Set 4 | chissamba
# Processing Record 9 of Set 4 | gueltat zemmour
# City not found. Skipping...
# Processing Record 10 of Set 4 | geraldton
# Processing Record 11 of Set 4 | vikulovo
# Processing Record 12 of Set 4 | glendive
# Processing Record 13 of Set 4 | lata
# Processing Record 14 of Set 4 | tralee
# Processing Record 15 of Set 4 | invercargill
# Processing Record 16 of Set 4 | ierapetra
# Processing Record 17 of Set 4 | saudarkrokur
# Processing Record 18 of Set 4 | bubaque
# Processing Record 19 of Set 4 | cooper's town
# Processing Record 20 of Set 4 | ilanskiy
# Processing Record 21 of Set 4 | villemur-sur-tarn
# Processing Record 22 of Set 4 | kristinestad
# Processing Record 23 of Set 4 | bontang
# Processing Record 24 of Set 4 | kikvidze
# Processing Record 25 of Set 4 | cat ba
# City not found. Skipping...
# Processing Record 26 of Set 4 | mananara
# Processing Record 27 of Set 4 | esbjerg
# Processing Record 28 of Set 4 | nabire
# Processing Record 29 of Set 4 | kamenka
# Processing Record 30 of Set 4 | tommot
# Processing Record 31 of Set 4 | paita
# Processing Record 32 of Set 4 | vila velha
# Processing Record 33 of Set 4 | lib
# Processing Record 34 of Set 4 | simrishamn
# Processing Record 35 of Set 4 | bredasdorp
# Processing Record 36 of Set 4 | talakan
# Processing Record 37 of Set 4 | qaryat suluq
# Processing Record 38 of Set 4 | gurmatkal
# Processing Record 39 of Set 4 | lihue
# Processing Record 40 of Set 4 | cidreira
# Processing Record 41 of Set 4 | saint-philippe
# Processing Record 42 of Set 4 | ta`u
# Processing Record 43 of Set 4 | dul'durga
# Processing Record 44 of Set 4 | kingscliff
# Processing Record 45 of Set 4 | akureyri
# Processing Record 46 of Set 4 | fort bragg
# Processing Record 47 of Set 4 | san patricio
# Processing Record 48 of Set 4 | vangaindrano
# Processing Record 49 of Set 4 | togur
# Processing Record 0 of Set 5 | yongfeng
# Processing Record 1 of Set 5 | palmer
# Processing Record 2 of Set 5 | elmendorf air force base
# City not found. Skipping...
# Processing Record 3 of Set 5 | notodden
# Processing Record 4 of Set 5 | aoulef
# Processing Record 5 of Set 5 | torghay
# Processing Record 6 of Set 5 | slave lake
# Processing Record 7 of Set 5 | laiyang
# Processing Record 8 of Set 5 | lagunas
# Processing Record 9 of Set 5 | selfoss
# Processing Record 10 of Set 5 | diu
# Processing Record 11 of Set 5 | humaita
# Processing Record 12 of Set 5 | kailua-kona
# Processing Record 13 of Set 5 | thompson
# Processing Record 14 of Set 5 | georgetown
# Processing Record 15 of Set 5 | port lincoln
# Processing Record 16 of Set 5 | chita
# Processing Record 17 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 18 of Set 5 | vadso
# Processing Record 19 of Set 5 | marsh harbour
# Processing Record 20 of Set 5 | nova sintra
# Processing Record 21 of Set 5 | hami
# Processing Record 22 of Set 5 | lima
# Processing Record 23 of Set 5 | gadzhiyevo
# Processing Record 24 of Set 5 | urengoy
# Processing Record 25 of Set 5 | talnakh
# Processing Record 26 of Set 5 | nemuro
# Processing Record 27 of Set 5 | waiuku
# Processing Record 28 of Set 5 | keflavik
# Processing Record 29 of Set 5 | bilibino
# Processing Record 30 of Set 5 | puerto deseado
# Processing Record 31 of Set 5 | antalaha
# Processing Record 32 of Set 5 | susuman
# Processing Record 33 of Set 5 | mugia
# Processing Record 34 of Set 5 | kayyerkan
# Processing Record 35 of Set 5 | nkove
# Processing Record 36 of Set 5 | syktyvkar
# Processing Record 37 of Set 5 | okhotsk
# Processing Record 38 of Set 5 | cottage grove
# Processing Record 39 of Set 5 | ocean pointe
# City not found. Skipping...
# Processing Record 40 of Set 5 | simpang empat
# Processing Record 41 of Set 5 | cochrane
# Processing Record 42 of Set 5 | aracati
# Processing Record 43 of Set 5 | kitimat
# Processing Record 44 of Set 5 | cable beach
# City not found. Skipping...
# Processing Record 45 of Set 5 | formosa do rio preto
# Processing Record 46 of Set 5 | kavieng
# Processing Record 47 of Set 5 | holualoa
# Processing Record 48 of Set 5 | altay
# Processing Record 49 of Set 5 | andreapol'
# Processing Record 0 of Set 6 | ake-eze
# Processing Record 1 of Set 6 | carnarvon
# Processing Record 2 of Set 6 | luganville
# Processing Record 3 of Set 6 | abraham's bay
# City not found. Skipping...
# Processing Record 4 of Set 6 | tadine
# Processing Record 5 of Set 6 | mount pearl
# Processing Record 6 of Set 6 | minas de marcona
# Processing Record 7 of Set 6 | klyuchi
# Processing Record 8 of Set 6 | waddan
# Processing Record 9 of Set 6 | colares
# Processing Record 10 of Set 6 | baskil
# Processing Record 11 of Set 6 | sao miguel do araguaia
# Processing Record 12 of Set 6 | stanisic
# Processing Record 13 of Set 6 | tolanaro
# Processing Record 14 of Set 6 | acarau
# Processing Record 15 of Set 6 | jamestown
# Processing Record 16 of Set 6 | tarko-sale
# Processing Record 17 of Set 6 | nadym
# Processing Record 18 of Set 6 | nogliki
# Processing Record 19 of Set 6 | rajpur
# Processing Record 20 of Set 6 | kota belud
# Processing Record 21 of Set 6 | samana
# City not found. Skipping...
# Processing Record 22 of Set 6 | stargard
# Processing Record 23 of Set 6 | mechetinskaya
# Processing Record 24 of Set 6 | zenica
# Processing Record 25 of Set 6 | bure
# Processing Record 26 of Set 6 | lintong
# Processing Record 27 of Set 6 | necochea
# Processing Record 28 of Set 6 | dunedin
# Processing Record 29 of Set 6 | atmore
# Processing Record 30 of Set 6 | belen
# Processing Record 31 of Set 6 | vielha
# Processing Record 32 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 33 of Set 6 | port alfred
# Processing Record 34 of Set 6 | lycksele
# Processing Record 35 of Set 6 | ghanzi
# Processing Record 36 of Set 6 | mao
# Processing Record 37 of Set 6 | saynshand
# Processing Record 38 of Set 6 | laguna
# Processing Record 39 of Set 6 | lucapa
# Processing Record 40 of Set 6 | manokwari
# Processing Record 41 of Set 6 | yanqul
# Processing Record 42 of Set 6 | tual
# Processing Record 43 of Set 6 | toliara
# Processing Record 44 of Set 6 | monchegorsk
# Processing Record 45 of Set 6 | port pirie
# Processing Record 46 of Set 6 | bethanie
# Processing Record 47 of Set 6 | enewetak
# Processing Record 48 of Set 6 | borogontsy
# Processing Record 49 of Set 6 | hitoyoshi
# Processing Record 0 of Set 7 | gamboma
# Processing Record 1 of Set 7 | hamilton
# Processing Record 2 of Set 7 | kavaratti
# Processing Record 3 of Set 7 | hermansverk
# Processing Record 4 of Set 7 | papao
# Processing Record 5 of Set 7 | iskateley
# Processing Record 6 of Set 7 | dehdasht
# Processing Record 7 of Set 7 | williamson
# Processing Record 8 of Set 7 | puerto baquerizo moreno
# Processing Record 9 of Set 7 | san jose de jachal
# Processing Record 10 of Set 7 | nyrob
# Processing Record 11 of Set 7 | pemba
# Processing Record 12 of Set 7 | al-`ula
# City not found. Skipping...
# Processing Record 13 of Set 7 | guiuan
# Processing Record 14 of Set 7 | masons bay
# City not found. Skipping...
# Processing Record 15 of Set 7 | whitecourt
# Processing Record 16 of Set 7 | swakopmund
# Processing Record 17 of Set 7 | poletayevo
# Processing Record 18 of Set 7 | avila
# Processing Record 19 of Set 7 | tazovsky
# Processing Record 20 of Set 7 | vredendal
# Processing Record 21 of Set 7 | saint-francois
# Processing Record 22 of Set 7 | port mathurin
# Processing Record 23 of Set 7 | callao
# Processing Record 24 of Set 7 | taguatinga
# Processing Record 25 of Set 7 | derzhavinsk
# Processing Record 26 of Set 7 | hasaki
# Processing Record 27 of Set 7 | colesberg
# Processing Record 28 of Set 7 | huarmey
# Processing Record 29 of Set 7 | fortuna
# Processing Record 30 of Set 7 | mahajanga
# Processing Record 31 of Set 7 | ebaye
# Processing Record 32 of Set 7 | ballina
# Processing Record 33 of Set 7 | agadez
# Processing Record 34 of Set 7 | kotlas
# Processing Record 35 of Set 7 | khorugh
# Processing Record 36 of Set 7 | savanna-la-mar
# Processing Record 37 of Set 7 | tsengel
# Processing Record 38 of Set 7 | sisimiut
# Processing Record 39 of Set 7 | las heras
# Processing Record 40 of Set 7 | mabaruma
# Processing Record 41 of Set 7 | oamaru
# Processing Record 42 of Set 7 | funafuti
# Processing Record 43 of Set 7 | nadi
# Processing Record 44 of Set 7 | muroto-misakicho
# Processing Record 45 of Set 7 | ha'il
# Processing Record 46 of Set 7 | vilyuchinsk
# Processing Record 47 of Set 7 | antofagasta
# Processing Record 48 of Set 7 | hotan
# Processing Record 49 of Set 7 | pachino
# Processing Record 0 of Set 8 | tangalle
# Processing Record 1 of Set 8 | newman
# Processing Record 2 of Set 8 | rio grande
# Processing Record 3 of Set 8 | mount isa
# Processing Record 30 of Set 9 | shenjiamen
# Processing Record 31 of Set 9 | vallenar
# Processing Record 32 of Set 9 | les anglais
# Processing Record 33 of Set 9 | hilo
# Processing Record 34 of Set 9 | korla
# Processing Record 35 of Set 9 | esil
# Processing Record 36 of Set 9 | santo antonio do sudoeste
# Processing Record 37 of Set 9 | quinta do anjo
# Processing Record 38 of Set 9 | leh
# Processing Record 39 of Set 9 | muzayri'
# City not found. Skipping...
# Processing Record 40 of Set 9 | khunti
# Processing Record 41 of Set 9 | kouroussa
# Processing Record 42 of Set 9 | haiku-pauwela
# Processing Record 43 of Set 9 | strathmore
# Processing Record 44 of Set 9 | mukalla
# Processing Record 45 of Set 9 | sayat
# Processing Record 46 of Set 9 | bandarbeyla
# Processing Record 47 of Set 9 | flin flon
# Processing Record 48 of Set 9 | andergrove
# Processing Record 49 of Set 9 | shangri-la
# City not found. Skipping...
# Processing Record 0 of Set 10 | pokhara
# Processing Record 1 of Set 10 | barra de santo antonio
# Processing Record 2 of Set 10 | aleysk
# Processing Record 3 of Set 10 | sussex
# Processing Record 4 of Set 10 | padangsidempuan
# Processing Record 5 of Set 10 | qasr-e qand
# City not found. Skipping...
# Processing Record 6 of Set 10 | san lawrenz
# Processing Record 7 of Set 10 | riosucio
# Processing Record 8 of Set 10 | port saint john's
# Processing Record 9 of Set 10 | fuzesgyarmat
# Processing Record 10 of Set 10 | constantia
# Processing Record 11 of Set 10 | shalkar
# Processing Record 12 of Set 10 | verkh-chebula
# Processing Record 13 of Set 10 | namibe
# Processing Record 14 of Set 10 | zheleznodorozhnyy
# Processing Record 15 of Set 10 | palikir - national government center
# Processing Record 16 of Set 10 | hammerfest
# Processing Record 17 of Set 10 | khvalynsk
# Processing Record 18 of Set 10 | nuuk
# Processing Record 19 of Set 10 | grand island
# Processing Record 20 of Set 10 | coquimbo
# Processing Record 21 of Set 10 | port macquarie
# Processing Record 22 of Set 10 | manaure
# Processing Record 23 of Set 10 | richards bay
# Processing Record 24 of Set 10 | ad dabbah
# Processing Record 25 of Set 10 | nueva gerona
# Processing Record 26 of Set 10 | ar ruways
# Processing Record 27 of Set 10 | wad az zaki
# Processing Record 28 of Set 10 | moyale
# Processing Record 29 of Set 10 | meadow lake
# Processing Record 30 of Set 10 | santa elena de uairen
# Processing Record 31 of Set 10 | luderitz
# Processing Record 32 of Set 10 | kirakira
# Processing Record 33 of Set 10 | chiri-yurt
# Processing Record 34 of Set 10 | zilair
# Processing Record 35 of Set 10 | masterton
# Processing Record 36 of Set 10 | timbo
# Processing Record 37 of Set 10 | vilyuysk
# Processing Record 38 of Set 10 | cromwell
# Processing Record 39 of Set 10 | onega
# Processing Record 40 of Set 10 | bako
# Processing Record 41 of Set 10 | mossel bay
# Processing Record 42 of Set 10 | djambala
# Processing Record 43 of Set 10 | ariquemes
# Processing Record 44 of Set 10 | freetown
# Processing Record 45 of Set 10 | plastun
# Processing Record 46 of Set 10 | checker hall
# City not found. Skipping...
# Processing Record 47 of Set 10 | mo i rana
# Processing Record 48 of Set 10 | sulphur
# Processing Record 49 of Set 10 | arrifes
# Processing Record 0 of Set 11 | udachny
# Processing Record 1 of Set 11 | dwarka
# Processing Record 2 of Set 11 | terenozek
# Processing Record 3 of Set 11 | peace river
# Processing Record 4 of Set 11 | kegeyli shahar
# Processing Record 5 of Set 11 | qoryooley
# Processing Record 6 of Set 11 | tamandare
# Processing Record 7 of Set 11 | bengkulu
# Processing Record 8 of Set 11 | howard springs
# Processing Record 9 of Set 11 | barabai
# Processing Record 10 of Set 11 | mahbubabad
# Processing Record 11 of Set 11 | al jawf
# Processing Record 12 of Set 11 | ad-damazin
# Processing Record 13 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 14 of Set 11 | tynda
# Processing Record 15 of Set 11 | padampur
# Processing Record 16 of Set 11 | nookat
# City not found. Skipping...
# Processing Record 17 of Set 11 | fisterra
# Processing Record 18 of Set 11 | narasannapeta
# Processing Record 19 of Set 11 | kargasok
# Processing Record 20 of Set 11 | paraparaumu
# Processing Record 21 of Set 11 | egilsstadir
# Processing Record 22 of Set 11 | nizhnevartovsk
# Processing Record 23 of Set 11 | semnan
# Processing Record 24 of Set 11 | tyul'kubas
# City not found. Skipping...
# Processing Record 25 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 26 of Set 11 | naze
# Processing Record 27 of Set 11 | gas city
# Processing Record 28 of Set 11 | oranjemund
# Processing Record 29 of Set 11 | sur
# Processing Record 30 of Set 11 | monrovia
# Processing Record 31 of Set 11 | kangding
# Processing Record 32 of Set 11 | bonthe
# Processing Record 33 of Set 11 | as sulayyil
# Processing Record 34 of Set 11 | lhokseumawe
# Processing Record 35 of Set 11 | bhamo
# Processing Record 36 of Set 11 | merizo village
# Processing Record 37 of Set 11 | vuktyl
# Processing Record 38 of Set 11 | kourou
# Processing Record 39 of Set 11 | salinopolis
# Processing Record 40 of Set 11 | vila franca do campo
# Processing Record 41 of Set 11 | karasburg
# Processing Record 42 of Set 11 | devinuwara
# City not found. Skipping...
# Processing Record 43 of Set 11 | alaior
# Processing Record 44 of Set 11 | baardheere
# Processing Record 45 of Set 11 | igarka
# Processing Record 46 of Set 11 | bratsk
# Processing Record 47 of Set 11 | lazaro cardenas
# Processing Record 48 of Set 11 | daye
# Processing Record 49 of Set 11 | kizner
# Processing Record 0 of Set 12 | ilam
# Processing Record 1 of Set 12 | mulayjah
# Processing Record 2 of Set 12 | fuvahmulah
# City not found. Skipping...
# Processing Record 3 of Set 12 | banda aceh
# Processing Record 4 of Set 12 | tabas
# Processing Record 5 of Set 12 | loreto
# Processing Record 6 of Set 12 | marte
# Processing Record 7 of Set 12 | lompoc
# Processing Record 8 of Set 12 | neya
# Processing Record 9 of Set 12 | koz'modem'yansk
# Processing Record 10 of Set 12 | bandar lampung
# Processing Record 11 of Set 12 | pampierstad
# Processing Record 12 of Set 12 | mili
# Processing Record 13 of Set 12 | murun-kuren
# Processing Record 14 of Set 12 | nakuru
# Processing Record 15 of Set 12 | ojinaga
# Processing Record 16 of Set 12 | alofi
# Processing Record 17 of Set 12 | live oak
# Processing Record 18 of Set 12 | culfa
# Processing Record 19 of Set 12 | qulsary
# Processing Record 20 of Set 12 | leninskoye
# Processing Record 21 of Set 12 | taltal
# Processing Record 22 of Set 12 | lorengau
# Processing Record 23 of Set 12 | caleta de carquin
# Processing Record 24 of Set 12 | kyzyl-mazhalyk
# Processing Record 25 of Set 12 | paracuru
# Processing Record 26 of Set 12 | smach mean chey
# City not found. Skipping...
# Processing Record 27 of Set 12 | suntar
# Processing Record 28 of Set 12 | lent'ekhi
# Processing Record 29 of Set 12 | manakara
# Processing Record 30 of Set 12 | yuzhno-kurilsk
# Processing Record 31 of Set 12 | talitsy
# Processing Record 32 of Set 12 | port shepstone
# Processing Record 33 of Set 12 | harnai
# Processing Record 34 of Set 12 | puerto cabezas
# Processing Record 35 of Set 12 | kenora
# Processing Record 36 of Set 12 | whakatane
# Processing Record 37 of Set 12 | marand
# Processing Record 38 of Set 12 | san ignacio
# Processing Record 39 of Set 12 | dipayal
# Processing Record 40 of Set 12 | chefchaouene
# Processing Record 41 of Set 12 | kununurra
# Processing Record 42 of Set 12 | polyarnyy
# Processing Record 43 of Set 12 | ambon
# Processing Record 44 of Set 12 | tosontsengel
# Processing Record 45 of Set 12 | nagqu
# Processing Record 46 of Set 12 | kiamba
# Processing Record 47 of Set 12 | nishinoomote
# Processing Record 48 of Set 12 | mecca
# Processing Record 49 of Set 12 | businga
# Processing Record 0 of Set 13 | kapsowar
# City not found. Skipping...
# Processing Record 1 of Set 13 | le port
# Processing Record 2 of Set 13 | mejit
# Processing Record 3 of Set 13 | caister-on-sea
# Processing Record 4 of Set 13 | dvurechensk
# Processing Record 5 of Set 13 | yeppoon city centre
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          572
# Lat           572
# Lng           572
# Max Temp      572
# Humidity      572
# Cloudiness    572
# Wind Speed    572
# Country       572
# Date          572
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500  70.2167     37.71        76          73
# 1          dickinson  29.4608 -95.0513    101.08        56          75
# 2            bestobe  52.4994  73.0975     71.44        44          72
# 3             luanda  -8.8368  13.2343     71.60        83          75
# 4            iqaluit  63.7506 -68.5145     46.13        87         100
#
#    Wind Speed Country        Date
# 0       31.90      TF  1690058495
# 1        6.91      US  1690058496
# 2        4.23      KZ  1690058496
# 3        8.05      AO  1690058496
# 4        4.61      CA  1690058497

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500  70.2167     37.71        76          73
# 1                dickinson  29.4608 -95.0513    101.08        56          75
# 2                  bestobe  52.4994  73.0975     71.44        44          72
# 3                   luanda  -8.8368  13.2343     71.60        83          75
# 4                  iqaluit  63.7506 -68.5145     46.13        87         100
#
#          Wind Speed Country        Date
# City_ID
# 0             31.90      TF  1690058495
# 1              6.91      US  1690058496
# 2              4.23      KZ  1690058496
# 3              8.05      AO  1690058496
# 4              4.61      CA  1690058497

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter(x = "Lat", y = "Max Temp")

# Incorporate the other graph properties
plt.title("Latitude Vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature in Fahrenheit")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot.scatter(x = "Lat", y = "Humidity")

# Incorporate the other graph properties
plt.title("Latitude Vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot.scatter(x = "Lat", y = "Cloudiness")

# Incorporate the other graph properties
plt.title("Latitude Vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot.scatter(x = "Lat", y = "Wind Speed")

# Incorporate the other graph properties
plt.title("Latitude Vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def regression (x_values, y_values, annotate, ylabel, title): 
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress,"r-")
    plt.annotate(line_eq, annotate, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()
    correlation = pearsonr(x_values, y_values) #directly imported on cell 1 so does not need st. 
    print(f"{correlation}.")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
northern_hemi_df.count()
# Out:
# City          403
# Lat           403
# Lng           403
# Max Temp      403
# Humidity      403
# Cloudiness    403
# Wind Speed    403
# Country       403
# Date          403
# dtype: int64

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
southern_hemi_df.count()
# Out:
# City          169
# Lat           169
# Lng           169
# Max Temp      169
# Humidity      169
# Cloudiness    169
# Wind Speed    169
# Country       163
# Date          169
# dtype: int64

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
annotate = (5,45)
ylabel = "Max Temperature in Fahrenheit"
title = "Temperature vs. Latitude"
regression (x_values, y_values, annotate, ylabel, title)

# statistic close to -1 inverse relationship this ne is fairly strong
# pvalue is telling you how likely is it random chance, you want lower than 0.05 then small chances. this is way less than that so 
# the chances are likely correlated and not random
# Out:
# PearsonRResult(statistic=-0.6408197329766083, pvalue=5.6452427507519e-48).

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
annotate = (-22, 35)
ylabel = "Max Temperature in Fahrenheit"
title = "Temperature vs. Latitude"
regression (x_values, y_values, annotate, ylabel, title)
# Out:
# PearsonRResult(statistic=0.8499590238750996, pvalue=2.4049883247938977e-48).

# %% [markdown]
# **Discussion about the linear relationship:** There is a strong correlation between the distance to the equator and maximum tempoerature. This means the higher the temperature, the closer to the equator. The p value also indicates this correlation is not by random chance.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
annotate = (50,10)
ylabel = "Humidity"
title = "Humidity vs. Northern Hemisphere Latitude"
regression (x_values, y_values, annotate, ylabel, title)
# Out:
# PearsonRResult(statistic=0.08113543335394557, pvalue=0.10386341494448319).

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
annotate = (-50,30)
ylabel = "Humidity"
title = "Humidity vs. Southern Hemisphere Latitude"
regression (x_values, y_values, annotate, ylabel, title)
# Out:
# PearsonRResult(statistic=-0.20862211747352122, pvalue=0.006489279799348467).

# %% [markdown]
# **Discussion about the linear relationship:** There is a weak negative correlation between humidity and latitude for both, nothern and southern hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
annotate = (5,45)
ylabel = "Cloudiness"
title = "Cloudiness vs. Northern Hemisphere Latitude"
regression (x_values, y_values, annotate, ylabel, title)
# Out:
# Correlation is PearsonRResult(statistic=-0.022348837097515714, pvalue=0.6546497576780707).

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
annotate = (-55, 3)
ylabel = "Cloudiness"
title = "Cloudiness vs. Southern Hemisphere Latitude"
regression (x_values, y_values, annotate, ylabel, title)
# Out:
# Correlation is PearsonRResult(statistic=-0.1571169074428683, pvalue=0.041345454297664105).

# %% [markdown]
# **Discussion about the linear relationship:** There is not a significant correlation regarding cloudiness and latitude for either southern or nothern hemisphere. However, it would be interesting to see the cloudiness and the longitude correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
annotate = (45,28)
ylabel = "Wind Speed"
title = "Wind Speed vs. Northern Hemisphere Latitude"
regression (x_values, y_values, annotate, ylabel, title)
# Out:
# Correlation is PearsonRResult(statistic=-0.199693040911891, pvalue=5.411792240086797e-05).

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
annotate = (-27,27)
ylabel = "Wind Speed"
title = "Wind Speed vs. Southern Hemisphere Latitude"
regression (x_values, y_values, annotate, ylabel, title)
# Out:
# Correlation is PearsonRResult(statistic=-0.062969338556844, pvalue=0.41602686757771246).

# %% [markdown]
# **Discussion about the linear relationship:** There is a weak, negative correlation between wind speed and latitude for both, southern and nothern hemispheres.
